# %% [markdown]
# # 2019 - Singapore Weather Analysis

# %%
# Import Pandas
import pandas as pd

# Add csv file
df = pd.read_csv("weather_clean.csv")
# Out:
#        Unnamed: 0        Date  Year  Month  Day  Daily Rainfall Total (mm)  \
# 0               0  2019-06-30  2019      6   30                        0.0
# 1               1  2019-06-29  2019      6   29                       18.4
# 2               2  2019-06-28  2019      6   28                        0.0
# 3               3  2019-06-27  2019      6   27                        0.0
# 4               4  2019-06-26  2019      6   26                        0.0
# ...           ...         ...   ...    ...  ...                        ...
# 12509       13325  1983-01-05  1983      1    5                        0.0
# 12510       13326  1983-01-04  1983      1    4                        0.0
# 12511       13327  1983-01-03  1983      1    3                        2.9
# 12512       13328  1983-01-02  1983      1    2                        0.4
# 12513       13329  1983-01-01  1983      1    1                        0.3
#
#        Mean Temperature (°C)  Maximum Temperature (°C)  \
# ...
